# %% [markdown]
# ## Creational design patterns

# %% [markdown]
# ### 1. used to construct objects such that they can be decoupled from their implementing system

# %% [markdown]
# ### 2. Provides ways to create objects

# %% [markdown]
# ## 1. Singleton class

# %% [markdown]
# इसमें class का सिर्फ एक ही object बनता है।
#
# Real Use Case
#
# * Database connection
#
# * Logger
#
# * Configuration manager

# %%
class DBConnection:
    
    def __new__(cls, *args, **kwargs):
        if not hasattr(cls, "_instance"):
            cls._instance = super().__new__(cls, *args, **kwargs)
        return cls._instance

# %%
a = DBConnection()

# %%
b = DBConnection()

# %%
a is b
# Out:
# True

# %%
id(a)
# Out:
# 2062383827096

# %%
id(b)
# Out:
# 2062383827096

# %% [markdown]
# ### using inheritance

# %%
class DBConn:
    _shared = {}
    def __init__(self):
        self.__dict__ = self._shared

# %%
class Singleton(DBConn):
    def __init__(self):
        super().__init__()

# %%
a = Singleton()

# %%
b = Singleton()

# %%
a is b
# Out:
# False

# %%
a.name = "shani"

# %%
b.name
# Out:
# 'shani'

# %%
b.name = "ajay"

# %%
a.name
# Out:
# 'ajay'

# %% [markdown]
# ### using decorators

# %%
class SingletonPattern:
    
    def __init__(self, klass):
        self.klass = klass
        self._instance = None
        
    def __call__(self):
        if self._instance is None:
            self._instance = self.klass()
        return self._instance

# %%
@SingletonPattern
class Logger:
    pass

# %%
a = Logger()

# %%
b = Logger()

# %%
a.name = "rahul"

# %%
b.name
# Out:
# 'rahul'

# %%
a.name
# Out:
# 'rahul'

# %%
b.name = "amit"

# %%
a.name
# Out:
# 'amit'

# %% [markdown]
# # 2. Factory Method

# %% [markdown]
# ### simple Factory method

# %% [markdown]
# Object creation subclasses decide करती हैं।

# %%
from abc import ABC, abstractmethod

# %%
class Dept(ABC):
    @abstractmethod
    def role(self, *args, **kwargs): ...

# %%
class Hr(Dept):
    def role(self):
        return "role is hiring new candidate"

# %%
class Developer(Dept):
    def role(self):
        return "role is developing site and maintaning them"

# %%
class DepartmentFactory:
    
    """ to create object of deferent department you can use create_dept or create_dept2 method both are same"""
    
    def create_dept(self, name):
        dept = {
            "hr" : Hr(),
            "developer": Developer()
        }
        
        return dept.get(name, "Department not found")
    
    # OR
    def craate_dept2(self, name):
        if name == "hr":
            hr = Hr()
            return hr
        elif name == "developer":
            dev = Developer()
            return dev
        else:
            return "department not found"

# %%
dept = DepartmentFactory()

# %%
hr = dept.create_dept("hr")

# %%
hr

# %%
hr.role()
# Out:
# 'role is hiring new candidate'

# %% [markdown]
# ### 3. factory method and abstract factory method

# %% [markdown]
# Abstract factory
#
# Related objects का group create करता है।

# %% [markdown]
# Operating System UI
#
# * Windows button
#
# * Windows checkbox
#
# * Mac button
#
# * Mac checkbox
#
# Factory decide करेगी।

# %% [markdown]
# ##### step1 for create abstract class

# %%
class Shape(ABC):
    
    def draw(self): ...

# %% [markdown]
# ##### step2 create concrete class

# %%
class Circle(Shape):
    
    def draw(self):
        return "circle shape"

# %%
class Triangle(Shape):
    
    def draw(self):
        return "triange shape"

# %%
class RoundedCircle(Shape):
    
    def draw(self):
        return "circle shape"

# %%
class RoundedTriangle(Shape):
    
    def draw(self):
        return "triange shape"

# %% [markdown]
# ##### step3 create factory abstract class

# %%
class Factory(ABC):
    
    def shape(self): ...

# %% [markdown]
# ##### step4 create factory

# %%
class NormalFactory(Factory):
    
    def shape(self, shape):
        d = {
            "circle": Circle(),
            "triangle": Triangle()
        }
        
        return d.get(shape, "shape not found")

# %%
class Roundedfactory(Factory):
    
    def shape(self, shape):
        d = {
            "rcircle": RoundedCircle(),
            "rtriangel": RoundedTriangle()
        }
        
        return d.get(shape, "shape not found")

# %% [markdown]
# ##### step5 create abstrac factory

# %%
class Abstractfactory:
    
    def shape(self, shape):
        
        d = {
            "rfactory": Roundedfactory(),
            "nfactory": NormalFactory()
        }
        
        return d.get(shape, "factory not found")

# %%
d = Abstractfactory()

# %%
n_factory = d.shape("nfactory")

# %%
n_factory

# %%
circle = n_factory.shape("circle")

# %%
circle.draw()
# Out:
# 'circle shape'

# %%
triange = n_factory.shape("triangle")
triange

# %%
triange.draw()
# Out:
# 'triange shape'

# %% [markdown]
# # 3. Prototype desing pattern

# %% [markdown]
# Existing object को clone करके नया object बनाना।

# %% [markdown]
# Real use:
#
# * Game development
#
# * Object templates

# %%
import copy 

class Prototype:
    def clone(self):
        return copy.deepcopy(self)

# %%
class Student(Prototype):
    def __init__(self, name, address, age):
        self.name = name
        self.age = age
        self.address = address
         
    def __str__(self):
        return f"Student({name}, {address}, {age})"

# %%
st = Student("shani", "allahabad", 26)
st

# %%
b = st.clone()

# %%
b.name
# Out:
# 'shani'

# %%
b.age
# Out:
# 26

# %%
st.age
# Out:
# 26

# %%
b.name = "ankit"

# %%
b.name
# Out:
# 'ankit'

# %%
st.name
# Out:
# 'shani'

# %% [markdown]
# # Builder Design Pattern

# %% [markdown]
# Complex object को step-by-step build करने के लिए।

# %% [markdown]
# ### without builder

# %%
class Phone:
    
    def __init__(self, name, model, ram, processor):
        self.name = name
        self.model = model
        self.ram = ram
        self.processor = processor

# %%
p = Phone("samsung", "s25", "16", "octa")
p.name
# Out:
# 'samsung'

# %%
p.ram
# Out:
# '16'

# %% [markdown]
# ### using builder

# %%
class Phone:
    
    def __init__(self):
        self.name = None
        self.model = None
        self.ram = None
        self.processor = None
        
    def set_name(self, name):
        self.name = name
        return self
        
    def set_model(self, model):
        self.model = model
        return self
    
    def set_ram(self, ram):
        self.ram = ram
        return self
    
    def set_processor(self, pro):
        self.processor = pro
        return self

# %%
p = Phone().set_name("Samsung").set_ram("32GB")
p.name
# Out:
# 'Samsung'

# %%
p.name
# Out:
# 'Samsung'

# %% [markdown]
# # or

# %%
class Phone:
    
    def __init__(self, name, brand):
        self.name = name   #required paramater
        self.model = brand
        self.ram = None
        self.processor = None
        
        
class PhoneBuilder(Phone):
    def __init__(self, name, brand):
        self.phone = Phone(name, brand)
    
    def set_ram(self, ram):
        self.phone.ram = ram
        return self
    
    def set_processor(self, pro):
        self.phone.processor = pro
        return self
    
    def build(self):
        return self.phone

# %%
ph = PhoneBuilder("Nokia", "34")\
.set_processor("octa")\
.build()

# %%
ph

# %%
ph.processor
# Out:
# 'octa'

# %% [markdown]
# # Query Builder

# %% [markdown]
# QueryBuilder
#    |
#    * |-- select()
#    * |-- where()
#    * |-- order_by()
#    * |-- build()

# %%
class QueryBuilder:

    def __init__(self):
        self.query = ""

    def select(self, table):
        self.query += f"SELECT * FROM {table}"
        return self

    def where(self, condition):
        self.query += f" WHERE {condition}"
        return self

    def order_by(self, column):
        self.query += f" ORDER BY {column}"
        return self

    def build(self):
        return self.query

# %%
query = (
    QueryBuilder()
    .select("users")
    .where("age > 20")
    .order_by("name")
    .where("name='shani'")
    .build()
)

print(query)
# Out:
# SELECT * FROM users WHERE age > 20 ORDER BY name WHERE name='shani'

# %%
class QueryBuilder:

    def __init__(self):
        self.table = ""
        self.conditions = []

    def select(self, table):
        self.table = table
        return self

    def where(self, condition):
        self.conditions.append(condition)
        return self

    def build(self):

        query = f"SELECT * FROM {self.table}"

        if self.conditions:
            query += " WHERE " + " AND ".join(self.conditions)

        return query

# %%
query = (
    QueryBuilder()
    .select("users")
    .where("age > 20")
    .where("name = 'shani'")
    .build()
)

print(query)
# Out:
# SELECT * FROM users WHERE age > 20 AND name = 'shani'

# %% [markdown]
# Real use case
#
# ORM frameworks
#
# * These tools internally use Query Builder pattern:
#
# * Django ORM
#
# * SQLAlchemy
#
# * TypeORM
#
# Example with SQLAlchemy

# %% [markdown]
# # HTTP request
